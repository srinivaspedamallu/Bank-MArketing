# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.cluster import KMeans
from sklearn import datasets
from io import StringIO
from sklearn.tree import export_graphviz
from sklearn.model_selection import train_test_split
from sklearn import tree
from sklearn import metrics
from sklearn.svm import SVC
# %matplotlib inline

# %%
# The code was removed by Watson Studio for sharing.
# Out:
#    age        job  marital    education  default housing loan    contact  \
# 0   56  housemaid  married     basic.4y       no      no   no  telephone
# 1   57   services  married  high.school  unknown      no   no  telephone
# 2   37   services  married  high.school       no     yes   no  telephone
# 3   40     admin.  married     basic.6y       no      no   no  telephone
# 4   56   services  married  high.school       no      no  yes  telephone
#
#   month day_of_week ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0   may         mon ...         1    999         0  nonexistent          1.1
# 1   may         mon ...         1    999         0  nonexistent          1.1
# 2   may         mon ...         1    999         0  nonexistent          1.1
# 3   may         mon ...         1    999         0  nonexistent          1.1
# 4   may         mon ...         1    999         0  nonexistent          1.1
#
#    cons.price.idx  cons.conf.idx  euribor3m  nr.employed   y
# ...

# %%
bank['default'].value_counts()
# Out:
# no         32588
# unknown     8597
# yes            3
# Name: default, dtype: int64

# %%
bank['job'].value_counts()
# Out:
# admin.           10422
# blue-collar       9254
# technician        6743
# services          3969
# management        2924
# retired           1720
# entrepreneur      1456
# self-employed     1421
# housemaid         1060
# unemployed        1014
# student            875
# unknown            330
# Name: job, dtype: int64

# %%
bank['job'].value_counts()
# Out:
# admin.           10422
# blue-collar       9254
# technician        6743
# services          3969
# management        2924
# retired           1720
# entrepreneur      1456
# self-employed     1421
# housemaid         1060
# unemployed        1014
# student            875
# unknown            330
# Name: job, dtype: int64

# %%
bank=bank.drop('job',axis=1)

# %%
bank=bank.drop('education',axis=1)

# %%
bank=bank.drop('default',axis=1)

# %%
bank=bank.drop('housing',axis=1)

# %%
bank=bank.drop('loan',axis=1)

# %%
bank=bank.drop('month',axis=1)

# %%
bank=bank.drop('contact',axis=1)

# %%
bank=bank.drop('day_of_week',axis=1)

# %%
bank
# Out:
#        age   marital  duration  campaign  pdays  previous     poutcome  \
# 0       56   married       261         1    999         0  nonexistent
# 1       57   married       149         1    999         0  nonexistent
# 2       37   married       226         1    999         0  nonexistent
# 3       40   married       151         1    999         0  nonexistent
# 4       56   married       307         1    999         0  nonexistent
# 5       45   married       198         1    999         0  nonexistent
# 6       59   married       139         1    999         0  nonexistent
# 7       41   married       217         1    999         0  nonexistent
# 8       24    single       380         1    999         0  nonexistent
# 9       25    single        50         1    999         0  nonexistent
# 10      41   married        55         1    999         0  nonexistent
# 11      25    single       222         1    999         0  nonexistent
# ...

# %%
g = sns.boxplot(x=bank["age"])
# Out:
# /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages/seaborn/categorical.py:462: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   box_data = remove_na(group_data)

# %%
sns.distplot(bank.age, bins=100)

# %%
g = sns.boxplot(x=bank["duration"])
# Out:
# /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages/seaborn/categorical.py:462: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   box_data = remove_na(group_data)

# %%
sns.distplot(bank.duration, bins=100)

# %%
from sklearn import preprocessing 
label_encoder = preprocessing.LabelEncoder() 
  
# Encode labels in column  
bank['marital']= label_encoder.fit_transform(bank['marital']) 
bank['marital'].unique()
# Out:
# array([1, 2, 0, 3])

# %%
bank
# Out:
#        age  marital  duration  campaign  pdays  previous     poutcome  \
# 0       56        1       261         1    999         0  nonexistent
# 1       57        1       149         1    999         0  nonexistent
# 2       37        1       226         1    999         0  nonexistent
# 3       40        1       151         1    999         0  nonexistent
# 4       56        1       307         1    999         0  nonexistent
# 5       45        1       198         1    999         0  nonexistent
# 6       59        1       139         1    999         0  nonexistent
# 7       41        1       217         1    999         0  nonexistent
# 8       24        2       380         1    999         0  nonexistent
# 9       25        2        50         1    999         0  nonexistent
# 10      41        1        55         1    999         0  nonexistent
# 11      25        2       222         1    999         0  nonexistent
# ...

# %%
bank['duration']= label_encoder.fit_transform(bank['duration']) 
  
bank['duration'].unique() 
bank
# Out:
#        age  marital  duration  campaign  pdays  previous     poutcome  \
# 0       56        1       261         1    999         0  nonexistent
# 1       57        1       149         1    999         0  nonexistent
# 2       37        1       226         1    999         0  nonexistent
# 3       40        1       151         1    999         0  nonexistent
# 4       56        1       307         1    999         0  nonexistent
# 5       45        1       198         1    999         0  nonexistent
# 6       59        1       139         1    999         0  nonexistent
# 7       41        1       217         1    999         0  nonexistent
# 8       24        2       380         1    999         0  nonexistent
# 9       25        2        50         1    999         0  nonexistent
# 10      41        1        55         1    999         0  nonexistent
# 11      25        2       222         1    999         0  nonexistent
# ...

# %%
bank['pdays']= label_encoder.fit_transform(bank['pdays']) 
  
bank['pdays'].unique() 
bank
# Out:
#        age  marital  duration  campaign  pdays  previous     poutcome  \
# 0       56        1       261         1     26         0  nonexistent
# 1       57        1       149         1     26         0  nonexistent
# 2       37        1       226         1     26         0  nonexistent
# 3       40        1       151         1     26         0  nonexistent
# 4       56        1       307         1     26         0  nonexistent
# 5       45        1       198         1     26         0  nonexistent
# 6       59        1       139         1     26         0  nonexistent
# 7       41        1       217         1     26         0  nonexistent
# 8       24        2       380         1     26         0  nonexistent
# 9       25        2        50         1     26         0  nonexistent
# 10      41        1        55         1     26         0  nonexistent
# 11      25        2       222         1     26         0  nonexistent
# ...

# %%
bank=bank.drop('previous',axis=1)

# %%
bank
# Out:
#        age  marital  duration  campaign  pdays     poutcome  emp.var.rate  \
# 0       56        1       261         1     26  nonexistent           1.1
# 1       57        1       149         1     26  nonexistent           1.1
# 2       37        1       226         1     26  nonexistent           1.1
# 3       40        1       151         1     26  nonexistent           1.1
# 4       56        1       307         1     26  nonexistent           1.1
# 5       45        1       198         1     26  nonexistent           1.1
# 6       59        1       139         1     26  nonexistent           1.1
# 7       41        1       217         1     26  nonexistent           1.1
# 8       24        2       380         1     26  nonexistent           1.1
# 9       25        2        50         1     26  nonexistent           1.1
# 10      41        1        55         1     26  nonexistent           1.1
# 11      25        2       222         1     26  nonexistent           1.1
# ...

# %%
bank['poutcome']= label_encoder.fit_transform(bank['poutcome']) 
  
bank['poutcome'].unique() 
bank
# Out:
#        age  marital  duration  campaign  pdays  poutcome  emp.var.rate  \
# 0       56        1       261         1     26         1           1.1
# 1       57        1       149         1     26         1           1.1
# 2       37        1       226         1     26         1           1.1
# 3       40        1       151         1     26         1           1.1
# 4       56        1       307         1     26         1           1.1
# 5       45        1       198         1     26         1           1.1
# 6       59        1       139         1     26         1           1.1
# 7       41        1       217         1     26         1           1.1
# 8       24        2       380         1     26         1           1.1
# 9       25        2        50         1     26         1           1.1
# 10      41        1        55         1     26         1           1.1
# 11      25        2       222         1     26         1           1.1
# ...

# %%
bank['emp.var.rate']= label_encoder.fit_transform(bank['emp.var.rate']) 
  
bank['emp.var.rate'].unique() 

bank['cons.conf.idx']= label_encoder.fit_transform(bank['cons.conf.idx']) 
  
bank['cons.conf.idx'].unique() 

bank['cons.price.idx']= label_encoder.fit_transform(bank['cons.price.idx']) 
  
bank['cons.price.idx'].unique()
# Out:
# array([18, 23, 17, 13, 15, 11,  6,  7, 10,  8,  9,  3,  0,  1,  2,  4,  5,
#        12, 14, 16, 20, 22, 19, 21, 24, 25])

# %%
bank
# Out:
#        age  marital  duration  campaign  pdays  poutcome  emp.var.rate  \
# 0       56        1       261         1     26         1             8
# 1       57        1       149         1     26         1             8
# 2       37        1       226         1     26         1             8
# 3       40        1       151         1     26         1             8
# 4       56        1       307         1     26         1             8
# 5       45        1       198         1     26         1             8
# 6       59        1       139         1     26         1             8
# 7       41        1       217         1     26         1             8
# 8       24        2       380         1     26         1             8
# 9       25        2        50         1     26         1             8
# 10      41        1        55         1     26         1             8
# 11      25        2       222         1     26         1             8
# ...

# %%
bank['euribor3m']= label_encoder.fit_transform(bank['euribor3m']) 
  
bank['euribor3m'].unique() 

bank['nr.employed']= label_encoder.fit_transform(bank['nr.employed']) 
  
bank['nr.employed'].unique() 

bank['y']= label_encoder.fit_transform(bank['y']) 
  
bank['y'].unique() 
bank
# Out:
#        age  marital  duration  campaign  pdays  poutcome  emp.var.rate  \
# 0       56        1       261         1     26         1             8
# 1       57        1       149         1     26         1             8
# 2       37        1       226         1     26         1             8
# 3       40        1       151         1     26         1             8
# 4       56        1       307         1     26         1             8
# 5       45        1       198         1     26         1             8
# 6       59        1       139         1     26         1             8
# 7       41        1       217         1     26         1             8
# 8       24        2       380         1     26         1             8
# 9       25        2        50         1     26         1             8
# 10      41        1        55         1     26         1             8
# 11      25        2       222         1     26         1             8
# ...

# %%
bankcl = bank

# %%
corr = bankcl.corr()
corr
# Out:
#                      age   marital  duration  campaign     pdays  poutcome  \
# age             1.000000 -0.389753 -0.000289  0.004594 -0.037413  0.019750
# marital        -0.389753  1.000000  0.010600 -0.007240 -0.035746  0.001912
# duration       -0.000289  0.010600  1.000000 -0.076374 -0.047820  0.034275
# campaign        0.004594 -0.007240 -0.076374  1.000000  0.052348  0.032586
# pdays          -0.037413 -0.035746 -0.047820  0.052348  1.000000 -0.486922
# poutcome        0.019750  0.001912  0.034275  0.032586 -0.486922  1.000000
# emp.var.rate    0.002171 -0.081916 -0.033560  0.146367  0.257204  0.192342
# cons.price.idx -0.006121 -0.055996  0.002990  0.124712  0.090808  0.198907
# cons.conf.idx   0.127955 -0.028307 -0.008391 -0.024284 -0.108948  0.166249
# euribor3m      -0.048132 -0.078735 -0.044162  0.133925  0.384668  0.089876
# nr.employed    -0.025735 -0.080046 -0.052959  0.143363  0.375548  0.087030
# ...

# %%
# Heatmap
plt.figure(figsize = (10,10))
cmap = sns.diverging_palette(220, 10, as_cmap=True)
sns.heatmap(corr, xticklabels=corr.columns.values, yticklabels=corr.columns.values, cmap=cmap, vmax=.3, center=0, square=True, linewidths=.5, cbar_kws={"shrink": .82})
plt.title('Heatmap of Correlation Matrix')
# Out:
# Text(0.5,1,'Heatmap of Correlation Matrix')

# %%
corr_deposite = pd.DataFrame(corr['campaign'].drop('campaign'))
corr_deposite.sort_values(by = 'campaign', ascending = False)
# Out:
#                 campaign
# emp.var.rate    0.146367
# nr.employed     0.143363
# euribor3m       0.133925
# cons.price.idx  0.124712
# pdays           0.052348
# poutcome        0.032586
# age             0.004594
# marital        -0.007240
# cons.conf.idx  -0.024284
# y              -0.066357
# duration       -0.076374

# %%
# Train-Test split: 20% test data
data_drop_deposite = bankcl.drop('pdays', 1)
label = bankcl.campaign
data_train, data_test, label_train, label_test = train_test_split(data_drop_deposite, label, test_size = 0.2, random_state = 50)

# %%
data_train
# Out:
#        age  marital  duration  campaign  poutcome  emp.var.rate  \
# 33479   32        1       548         2         1             3
# 36397   31        1       217         1         1             2
# 10925   28        2       466         2         1             9
# 8877    41        1        21         1         1             9
# 32199   44        2       318         1         0             3
# 8251    49        1       131         5         1             9
# 479     41        1       448         1         1             8
# 41036   38        2       254         1         0             5
# 36959   46        2       309         1         1             2
# 11172   41        1       512         1         1             9
# 34068   33        1        85         2         0             3
# 7025    52        2       223         4         1             8
# 21568   58        1       587         1         1             9
# 8400    58        1       183         2         1             9
# ...

# %%
dt2 = tree.DecisionTreeClassifier(random_state=8, max_depth=2)
dt2.fit(data_train,label_train)
dt2_score_train = dt2.score(data_train, label_train)
print("Training score: ",dt2_score_train)
dt2_score_test = dt2.score(data_test, label_test)
print("Accuracy: ",(dt2_score_test)*100.0)
# Out:
# Training score:  0.813414264036
# Accuracy:  81.9495023064

# %%
# Decision tree with depth = 3
dt3 = tree.DecisionTreeClassifier(random_state=8, max_depth=3)
dt3.fit(data_train, label_train)
dt3_score_train = dt3.score(data_train, label_train)
print("Training score: ",dt3_score_train)
dt3_score_test = dt3.score(data_test, label_test)
print("Accuracy: ",(dt3_score_test)*100.0)
# Out:
# Training score:  0.878209408194
# Accuracy:  88.2131585336

# %%
# Decision tree with depth = 4
dt4 = tree.DecisionTreeClassifier(random_state=8, max_depth=4)
dt4.fit(data_train, label_train)
dt4_score_train = dt4.score(data_train, label_train)
print("Training score: ",dt4_score_train)
dt4_score_test = dt4.score(data_test, label_test)
print("Accuracy: ",(dt4_score_test)*100.0)
# Out:
# Training score:  0.917359635812
# Accuracy:  91.9640689488

# %%
# Decision tree with depth = 6
dt6 = tree.DecisionTreeClassifier(random_state=8, max_depth=6)
dt6.fit(data_train, label_train)
dt6_score_train = dt6.score(data_train, label_train)
print("Training score: ",dt6_score_train)
dt6_score_test = dt6.score(data_test, label_test)
print("Accuracy: ",(dt6_score_test)*100)
# Out:
# Training score:  0.956084977238
# Accuracy:  95.994173343

# %%
from watson_machine_learning_client import WatsonMachineLearningAPIClient
# Out:
# /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# 2019-05-30 11:52:50,148 - watson_machine_learning_client.metanames - WARNING - 'AUTHOR_EMAIL' meta prop is deprecated. It will be ignored.

# %%
# The code was removed by Watson Studio for sharing.

# %%
client =WatsonMachineLearningAPIClient(wml_Credentials)

# %%
model_props={client.repository.ModelMetaNames.AUTHOR_NAME:"nivas",
            client.repository.ModelMetaNames.AUTHOR_EMAIL:"nivaspedamallu1405@gmail.com",
            client.repository.ModelMetaNames.NAME:"Bank Marketing"}

# %%
model_artifact=client.repository.store_model(dt6,meta_props=model_props)

# %%
published_model_uid=client.repository.get_model_uid(model_artifact)

# %%
published_model_uid
# Out:
# 'dc40abae-664e-444e-a352-63427924961e'

# %%
deployment=client.deployments.create(published_model_uid,name="Bank-Marketing")
# Out:
# #######################################################################################
#
# Synchronous deployment creation for uid: 'dc40abae-664e-444e-a352-63427924961e' started
#
# #######################################################################################
#
#
# INITIALIZING
# DEPLOY_SUCCESS
#
#
# ------------------------------------------------------------------------------------------------
# Successfully finished deployment creation, deployment_uid='ce0abce5-00e1-479d-b9cd-abee83ca97f7'
# ------------------------------------------------------------------------------------------------

# %%
scoring_endpoint=client.deployments.get_scoring_url(deployment)

# %%
scoring_endpoint
# Out:
# 'https://eu-gb.ml.cloud.ibm.com/v3/wml_instances/f90d4da3-77eb-4af1-b2f5-d134eea9de0f/deployments/ce0abce5-00e1-479d-b9cd-abee83ca97f7/online'
